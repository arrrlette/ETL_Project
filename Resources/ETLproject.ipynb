# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
automation_file = "automation_bystate.csv"
automation_df = pd.read_csv(automation_file)  
automation_df.head(50)
# Out:
#         SOC                                         Occupation  Probability  \
# 0   11-1011                                   Chief Executives       0.0150
# 1   11-1021                    General and Operations Managers       0.1600
# 2   11-2011                Advertising and Promotions Managers       0.0390
# 3   11-2021                                 Marketing Managers       0.0140
# 4   11-2022                                     Sales Managers       0.0130
# 5   11-2031          Public Relations and Fundraising Managers       0.0150
# 6   11-3011                   Administrative Services Managers       0.7300
# 7   11-3021          Computer and Information Systems Managers       0.0350
# 8   11-3031                                 Financial Managers       0.0690
# 9   11-3051                     Industrial Production Managers       0.0300
# 10  11-3061                                Purchasing Managers       0.0300
# ...

# %%
occupation_file = "occupation.csv"
occupation_df = pd.read_csv(occupation_file)
occupation_df.head()
# Out:
#   OCC_CODE               OCC_TITLE OCC_GROUP      TOT_EMP  EMP_PRSE H_MEAN  \
# 0  00-0000         All Occupations     total  140,400,040       0.1  23.86
# 1  11-0000  Management Occupations     major    7,090,790       0.2  56.74
# 2  11-1000          Top Executives     minor    2,465,800       0.2  61.03
# 3  11-1010        Chief Executives     broad      223,260       0.7  93.44
# 4  11-1011        Chief Executives  detailed      223,260       0.7  93.44
#
#     A_MEAN  MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0   49,630        0.1    9.27   11.60    17.81   28.92   45.45  19,290
# 1  118,020        0.1   22.76   32.99    48.46   70.72       #  47,330
# 2  126,950        0.2   20.58   31.45    49.19   78.35       #  42,810
# 3  194,350        0.4   33.55   54.86    87.12       #       #  69,780
# 4  194,350        0.4   33.55   54.86    87.12       #       #  69,780
#
#    A_PCT25 A_MEDIAN  A_PCT75 A_PCT90 ANNUAL HOURLY
# ...
